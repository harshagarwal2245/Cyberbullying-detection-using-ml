# %%
import matplotlib.pyplot as plt

# %%
x=[0,1,0.5,0.7,0.2,2,2.5,2.6,2.8,2]
y=[1,2,3,4,2,6,6.4,5,6.7,7,]
plt.scatter(x,y,c=["orange","orange","orange","orange","orange","blue","blue","blue","blue","blue"])
x1=[0,3]
y1=[7,0]
x2=[0,2.2]
y2=[5.9,0]
plt.plot(x1,y1,color="r")
plt.plot(x2,y2,color="r")
plt.show()

# %%
x=[[1,8,11]]
y
plt.scatter(x,y)
plt.show()

# %%
x=[[1,8,11],[1,11,8],[1,5,3]]
x[0]
# Out:
# [1, 8, 11]

# %%
import numpy as np

# %%
x=np.array(x)
x
# Out:
# array([[ 1,  8, 11],
#        [ 1, 11,  8],
#        [ 1,  5,  3]])

# %%
plt.scatter(x[:,1],x[:,2],c=y)

# %%
y=[0,1,0]
